# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### Data Visualisation - we can extract information and patterns by crating visuals and graphs , we can analyse insights.
# #### 5 visuals -->
# ##### 1. 2D Plot
# ##### 2. Scatter Plot
# ##### 3. Bar Chart
# ##### 4. Histogram
# ##### 5. Pie Chart
